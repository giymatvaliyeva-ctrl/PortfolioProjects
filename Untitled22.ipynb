# %% [markdown]
# <a href="https://colab.research.google.com/github/giymatvaliyeva-ctrl/Financial-Risk-Project/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
data=pd.read_csv('financial_risk_assessment.csv.zip')
data.head()
# Out:
#    Age      Gender Education Level Marital Status   Income  Credit Score  \
# 0   49        Male             PhD       Divorced  72799.0         688.0
# 1   57      Female      Bachelor's        Widowed      NaN         690.0
# 2   21  Non-binary        Master's         Single  55687.0         600.0
# 3   59        Male      Bachelor's         Single  26508.0         622.0
# 4   25  Non-binary      Bachelor's        Widowed  49427.0         766.0
#
#    Loan Amount Loan Purpose Employment Status  Years at Current Job  \
# 0      45713.0     Business        Unemployed                    19
# 1      33835.0         Auto          Employed                     6
# 2      36623.0         Home          Employed                     8
# 3      26541.0     Personal        Unemployed                     2
# 4      36528.0     Personal        Unemployed                    10
#
#   Payment History  Debt-to-Income Ratio  Assets Value  Number of Dependents  \
# 0            Poor              0.154313      120228.0                   0.0
# 1            Fair              0.148920       55849.0                   0.0
# 2            Fair              0.362398      180700.0                   3.0
# 3       Excellent              0.454964      157319.0                   3.0
# 4            Fair              0.143242      287140.0                   NaN
#
#               City State       Country  Previous Defaults  \
# 0   Port Elizabeth    AS        Cyprus                2.0
# 1  North Catherine    OH  Turkmenistan                3.0
# 2      South Scott    OK    Luxembourg                3.0
# 3       Robinhaven    PR        Uganda                4.0
# 4      New Heather    IL       Namibia                3.0
#
#    Marital Status Change Risk Rating
# 0                      2         Low
# 1                      2      Medium
# 2                      2      Medium
# 3                      2      Medium
# 4                      1         Low

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    15000 non-null  int64
#  1   Gender                 15000 non-null  object
#  2   Education Level        15000 non-null  object
#  3   Marital Status         15000 non-null  object
#  4   Income                 12750 non-null  float64
#  5   Credit Score           12750 non-null  float64
#  6   Loan Amount            12750 non-null  float64
#  7   Loan Purpose           15000 non-null  object
#  8   Employment Status      15000 non-null  object
#  9   Years at Current Job   15000 non-null  int64
#  10  Payment History        15000 non-null  object
#  11  Debt-to-Income Ratio   15000 non-null  float64
#  12  Assets Value           12750 non-null  float64
#  13  Number of Dependents   12750 non-null  float64
#  14  City                   15000 non-null  object
#  15  State                  15000 non-null  object
#  16  Country                15000 non-null  object
#  17  Previous Defaults      12750 non-null  float64
#  18  Marital Status Change  15000 non-null  int64
#  19  Risk Rating            15000 non-null  object
# dtypes: float64(7), int64(3), object(10)
# memory usage: 2.3+ MB

# %%
data.shape
# Out:
# (15000, 20)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Marital Status', 'Income',
#        'Credit Score', 'Loan Amount', 'Loan Purpose', 'Employment Status',
#        'Years at Current Job', 'Payment History', 'Debt-to-Income Ratio',
#        'Assets Value', 'Number of Dependents', 'City', 'State', 'Country',
#        'Previous Defaults', 'Marital Status Change', 'Risk Rating'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Age                         0
# Gender                      0
# Education Level             0
# Marital Status              0
# Income                   2250
# Credit Score             2250
# Loan Amount              2250
# Loan Purpose                0
# Employment Status           0
# Years at Current Job        0
# Payment History             0
# Debt-to-Income Ratio        0
# Assets Value             2250
# Number of Dependents     2250
# City                        0
# State                       0
# Country                     0
# Previous Defaults        2250
# Marital Status Change       0
# Risk Rating                 0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isna().sum()
# Out:
# Age                      0
# Gender                   0
# Education Level          0
# Marital Status           0
# Income                   0
# Credit Score             0
# Loan Amount              0
# Loan Purpose             0
# Employment Status        0
# Years at Current Job     0
# Payment History          0
# Debt-to-Income Ratio     0
# Assets Value             0
# Number of Dependents     0
# City                     0
# State                    0
# Country                  0
# Previous Defaults        0
# Marital Status Change    0
# Risk Rating              0
# dtype: int64

# %%
data.describe().style.background_gradient(cmap='Pastel2_r')
# Out:
# <style type="text/css">
# #T_5c3c7_row0_col0, #T_5c3c7_row0_col2, #T_5c3c7_row0_col4, #T_5c3c7_row0_col5, #T_5c3c7_row0_col7, #T_5c3c7_row0_col8, #T_5c3c7_row0_col9, #T_5c3c7_row7_col1, #T_5c3c7_row7_col3, #T_5c3c7_row7_col6 {
#   background-color: #b3e2cd;
#   color: #000000;
# }
# #T_5c3c7_row0_col1, #T_5c3c7_row0_col6, #T_5c3c7_row1_col0, #T_5c3c7_row1_col2, #T_5c3c7_row1_col4, #T_5c3c7_row1_col5, #T_5c3c7_row1_col7, #T_5c3c7_row1_col8, #T_5c3c7_row1_col9, #T_5c3c7_row2_col0, #T_5c3c7_row2_col2, #T_5c3c7_row2_col4, #T_5c3c7_row2_col5, #T_5c3c7_row2_col7, #T_5c3c7_row2_col8, #T_5c3c7_row2_col9, #T_5c3c7_row3_col0, #T_5c3c7_row3_col1, #T_5c3c7_row3_col2, #T_5c3c7_row3_col3, #T_5c3c7_row3_col4, #T_5c3c7_row3_col5, #T_5c3c7_row3_col6, #T_5c3c7_row3_col7, #T_5c3c7_row3_col8, #T_5c3c7_row3_col9, #T_5c3c7_row4_col0, #T_5c3c7_row4_col2, #T_5c3c7_row4_col4, #T_5c3c7_row4_col5, #T_5c3c7_row4_col7, #T_5c3c7_row4_col8, #T_5c3c7_row4_col9, #T_5c3c7_row5_col0, #T_5c3c7_row5_col2, #T_5c3c7_row5_col4, #T_5c3c7_row5_col5, #T_5c3c7_row5_col7, #T_5c3c7_row5_col8, #T_5c3c7_row5_col9, #T_5c3c7_row6_col0, #T_5c3c7_row6_col2, #T_5c3c7_row6_col4, #T_5c3c7_row6_col5, #T_5c3c7_row6_col7, #T_5c3c7_row6_col8, #T_5c3c7_row6_col9, #T_5c3c7_row7_col0, #T_5c3c7_row7_col2, #T_5c3c7_row7_col4, #T_5c3c7_row7_col5, #T_5c3c7_row7_col7, #T_5c3c7_row7_col8, #T_5c3c7_row7_col9 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_5c3c7_row0_col3, #T_5c3c7_row2_col1, #T_5c3c7_row2_col3, #T_5c3c7_row2_col6 {
#   background-color: #f1e2cc;
#   color: #000000;
# }
# #T_5c3c7_row1_col1, #T_5c3c7_row1_col6, #T_5c3c7_row5_col1, #T_5c3c7_row5_col3, #T_5c3c7_row5_col6 {
#   background-color: #f4cae4;
#   color: #000000;
# }
# #T_5c3c7_row1_col3 {
#   background-color: #e6f5c9;
#   color: #000000;
# }
# #T_5c3c7_row4_col1, #T_5c3c7_row4_col3, #T_5c3c7_row4_col6 {
#   background-color: #fff2ae;
#   color: #000000;
# }
# #T_5c3c7_row6_col1, #T_5c3c7_row6_col6 {
#   background-color: #fdcdac;
#   color: #000000;
# }
# #T_5c3c7_row6_col3 {
#   background-color: #cbd5e8;
#   color: #000000;
# }
# </style>
# <table id="T_5c3c7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c3c7_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_5c3c7_level0_col1" class="col_heading level0 col1" >Income</th>
#       <th id="T_5c3c7_level0_col2" class="col_heading level0 col2" >Credit Score</th>
#       <th id="T_5c3c7_level0_col3" class="col_heading level0 col3" >Loan Amount</th>
#       <th id="T_5c3c7_level0_col4" class="col_heading level0 col4" >Years at Current Job</th>
#       <th id="T_5c3c7_level0_col5" class="col_heading level0 col5" >Debt-to-Income Ratio</th>
#       <th id="T_5c3c7_level0_col6" class="col_heading level0 col6" >Assets Value</th>
#       <th id="T_5c3c7_level0_col7" class="col_heading level0 col7" >Number of Dependents</th>
#       <th id="T_5c3c7_level0_col8" class="col_heading level0 col8" >Previous Defaults</th>
#       <th id="T_5c3c7_level0_col9" class="col_heading level0 col9" >Marital Status Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c3c7_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_5c3c7_row0_col0" class="data row0 col0" >15000.000000</td>
#       <td id="T_5c3c7_row0_col1" class="data row0 col1" >12750.000000</td>
#       <td id="T_5c3c7_row0_col2" class="data row0 col2" >12750.000000</td>
#       <td id="T_5c3c7_row0_col3" class="data row0 col3" >12750.000000</td>
#       <td id="T_5c3c7_row0_col4" class="data row0 col4" >15000.000000</td>
#       <td id="T_5c3c7_row0_col5" class="data row0 col5" >15000.000000</td>
#       <td id="T_5c3c7_row0_col6" class="data row0 col6" >12750.000000</td>
#       <td id="T_5c3c7_row0_col7" class="data row0 col7" >12750.000000</td>
#       <td id="T_5c3c7_row0_col8" class="data row0 col8" >12750.000000</td>
#       <td id="T_5c3c7_row0_col9" class="data row0 col9" >15000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c3c7_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_5c3c7_row1_col0" class="data row1 col0" >43.452667</td>
#       <td id="T_5c3c7_row1_col1" class="data row1 col1" >69933.398510</td>
#       <td id="T_5c3c7_row1_col2" class="data row1 col2" >699.109098</td>
#       <td id="T_5c3c7_row1_col3" class="data row1 col3" >27450.010902</td>
#       <td id="T_5c3c7_row1_col4" class="data row1 col4" >9.476267</td>
#       <td id="T_5c3c7_row1_col5" class="data row1 col5" >0.350438</td>
#       <td id="T_5c3c7_row1_col6" class="data row1 col6" >159741.497176</td>
#       <td id="T_5c3c7_row1_col7" class="data row1 col7" >2.026510</td>
#       <td id="T_5c3c7_row1_col8" class="data row1 col8" >1.992471</td>
#       <td id="T_5c3c7_row1_col9" class="data row1 col9" >0.998467</td>
#     </tr>
#     <tr>
#       <th id="T_5c3c7_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_5c3c7_row2_col0" class="data row2 col0" >14.910732</td>
#       <td id="T_5c3c7_row2_col1" class="data row2 col1" >29163.626207</td>
#       <td id="T_5c3c7_row2_col2" class="data row2 col2" >57.229465</td>
#       <td id="T_5c3c7_row2_col3" class="data row2 col3" >12949.940135</td>
#       <td id="T_5c3c7_row2_col4" class="data row2 col4" >5.769707</td>
#       <td id="T_5c3c7_row2_col5" class="data row2 col5" >0.143919</td>
#       <td id="T_5c3c7_row2_col6" class="data row2 col6" >80298.115832</td>
#       <td id="T_5c3c7_row2_col7" class="data row2 col7" >1.411300</td>
#       <td id="T_5c3c7_row2_col8" class="data row2 col8" >1.416909</td>
#       <td id="T_5c3c7_row2_col9" class="data row2 col9" >0.813782</td>
#     </tr>
#     <tr>
#       <th id="T_5c3c7_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_5c3c7_row3_col0" class="data row3 col0" >18.000000</td>
#       <td id="T_5c3c7_row3_col1" class="data row3 col1" >20005.000000</td>
#       <td id="T_5c3c7_row3_col2" class="data row3 col2" >600.000000</td>
#       <td id="T_5c3c7_row3_col3" class="data row3 col3" >5000.000000</td>
#       <td id="T_5c3c7_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_5c3c7_row3_col5" class="data row3 col5" >0.100004</td>
#       <td id="T_5c3c7_row3_col6" class="data row3 col6" >20055.000000</td>
#       <td id="T_5c3c7_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_5c3c7_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_5c3c7_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c3c7_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_5c3c7_row4_col0" class="data row4 col0" >31.000000</td>
#       <td id="T_5c3c7_row4_col1" class="data row4 col1" >44281.500000</td>
#       <td id="T_5c3c7_row4_col2" class="data row4 col2" >650.000000</td>
#       <td id="T_5c3c7_row4_col3" class="data row4 col3" >16352.500000</td>
#       <td id="T_5c3c7_row4_col4" class="data row4 col4" >4.000000</td>
#       <td id="T_5c3c7_row4_col5" class="data row4 col5" >0.227386</td>
#       <td id="T_5c3c7_row4_col6" class="data row4 col6" >90635.250000</td>
#       <td id="T_5c3c7_row4_col7" class="data row4 col7" >1.000000</td>
#       <td id="T_5c3c7_row4_col8" class="data row4 col8" >1.000000</td>
#       <td id="T_5c3c7_row4_col9" class="data row4 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c3c7_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_5c3c7_row5_col0" class="data row5 col0" >43.000000</td>
#       <td id="T_5c3c7_row5_col1" class="data row5 col1" >69773.000000</td>
#       <td id="T_5c3c7_row5_col2" class="data row5 col2" >699.000000</td>
#       <td id="T_5c3c7_row5_col3" class="data row5 col3" >27544.000000</td>
#       <td id="T_5c3c7_row5_col4" class="data row5 col4" >9.000000</td>
#       <td id="T_5c3c7_row5_col5" class="data row5 col5" >0.350754</td>
#       <td id="T_5c3c7_row5_col6" class="data row5 col6" >159362.000000</td>
#       <td id="T_5c3c7_row5_col7" class="data row5 col7" >2.000000</td>
#       <td id="T_5c3c7_row5_col8" class="data row5 col8" >2.000000</td>
#       <td id="T_5c3c7_row5_col9" class="data row5 col9" >1.000000</td>
#     </tr

# %%
duplicates = data.duplicated().sum()
print(f'The data set contains {duplicates} values')
# Out:
# The data set contains 0 values

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['Age'],color='blue')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
data['Gender'].value_counts().sort_values(ascending=False) \
.plot(kind='pie',
      explode=[0,0,0.1],
      labels=['Female','Non-binary','Male'],
      colors=['#ffb703','#c1121f','#ff99c8'],
      autopct='%1.2f%%',
      shadow=True)
plt.title('Gender distribution in the data')
plt.show()

# %%
data['Education Level'].value_counts().sort_values(ascending=False)\
.plot(kind='bar', figsize=(10,5), color=['#ffd60a','#84a59d','#f15bb5','#7209b7'])
plt.xlabel('Education Level')
plt.ylabel('Count of values')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data,x='Gender',hue='Marital Status',multiple='dodge',shrink=.8)
plt.xlabel('Gender')
plt.ylabel('Count of values')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.relplot(x='Age', y='Income', data = data[:500],hue='Loan Purpose')
plt.title('The relation between Age and income with loan purpose')
plt.xlabel('Age')
plt.ylabel('Income')
plt.show()

# %%
employe=pd.DataFrame(data.groupby('Gender')['Employment Status'].value_counts())
employe.unstack().style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_38cee_row0_col0, #T_38cee_row2_col1, #T_38cee_row2_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_38cee_row0_col1, #T_38cee_row0_col2, #T_38cee_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_38cee_row1_col1 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_38cee_row1_col2 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_38cee_row2_col0 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# </style>
# <table id="T_38cee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38cee_level0_col0" class="col_heading level0 col0" colspan="3">count</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Employment Status</th>
#       <th id="T_38cee_level1_col0" class="col_heading level1 col0" >Employed</th>
#       <th id="T_38cee_level1_col1" class="col_heading level1 col1" >Self-employed</th>
#       <th id="T_38cee_level1_col2" class="col_heading level1 col2" >Unemployed</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38cee_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_38cee_row0_col0" class="data row0 col0" >1709</td>
#       <td id="T_38cee_row0_col1" class="data row0 col1" >1639</td>
#       <td id="T_38cee_row0_col2" class="data row0 col2" >1642</td>
#     </tr>
#     <tr>
#       <th id="T_38cee_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_38cee_row1_col0" class="data row1 col0" >1648</td>
#       <td id="T_38cee_row1_col1" class="data row1 col1" >1654</td>
#       <td id="T_38cee_row1_col2" class="data row1 col2" >1649</td>
#     </tr>
#     <tr>
#       <th id="T_38cee_level0_row2" class="row_heading level0 row2" >Non-binary</th>
#       <td id="T_38cee_row2_col0" class="data row2 col0" >1669</td>
#       <td id="T_38cee_row2_col1" class="data row2 col1" >1698</td>
#       <td id="T_38cee_row2_col2" class="data row2 col2" >1692</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.head(1)
# Out:
#    Age Gender Education Level Marital Status   Income  Credit Score  \
# 0   49   Male             PhD       Divorced  72799.0         688.0
#
#    Loan Amount Loan Purpose Employment Status  Years at Current Job  \
# 0      45713.0     Business        Unemployed                    19
#
#   Payment History  Debt-to-Income Ratio  Assets Value  Number of Dependents  \
# 0            Poor              0.154313      120228.0                   0.0
#
#              City State Country  Previous Defaults  Marital Status Change  \
# 0  Port Elizabeth    AS  Cyprus                2.0                      2
#
#   Risk Rating
# 0         Low

# %%
aver_credit_score=pd.DataFrame(data.groupby('Gender')['Credit Score'].mean().sort_values(ascending=False))
aver_credit_score.style.background_gradient(cmap='winter_r')
# Out:
# <style type="text/css">
# #T_eebac_row0_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_eebac_row1_col0 {
#   background-color: #00a2ae;
#   color: #f1f1f1;
# }
# #T_eebac_row2_col0 {
#   background-color: #00ff80;
#   color: #000000;
# }
# </style>
# <table id="T_eebac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eebac_level0_col0" class="col_heading level0 col0" >Credit Score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eebac_level0_row0" class="row_heading level0 row0" >Non-binary</th>
#       <td id="T_eebac_row0_col0" class="data row0 col0" >699.839265</td>
#     </tr>
#     <tr>
#       <th id="T_eebac_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_eebac_row1_col0" class="data row1 col0" >698.985245</td>
#     </tr>
#     <tr>
#       <th id="T_eebac_level0_row2" class="row_heading level0 row2" >Female</th>
#       <td id="T_eebac_row2_col0" class="data row2 col0" >698.492822</td>
#     </tr>
#   </tbody>
# </table>

# %%
Education_exp=pd.DataFrame(data.groupby('Education Level')['Years at Current Job'].value_counts().sort_values(ascending=False))
Education_exp.unstack().style.background_gradient(cmap='copper_r')
# Out:
# <style type="text/css">
# #T_f74a9_row0_col0, #T_f74a9_row0_col1, #T_f74a9_row0_col4, #T_f74a9_row0_col5, #T_f74a9_row0_col6, #T_f74a9_row0_col7, #T_f74a9_row1_col9, #T_f74a9_row1_col13, #T_f74a9_row1_col17, #T_f74a9_row1_col19, #T_f74a9_row2_col2, #T_f74a9_row2_col15, #T_f74a9_row2_col18, #T_f74a9_row3_col3, #T_f74a9_row3_col8, #T_f74a9_row3_col10, #T_f74a9_row3_col11, #T_f74a9_row3_col12, #T_f74a9_row3_col14, #T_f74a9_row3_col16 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f74a9_row0_col2, #T_f74a9_row0_col10 {
#   background-color: #1a100a;
#   color: #f1f1f1;
# }
# #T_f74a9_row0_col3 {
#   background-color: #f29962;
#   color: #000000;
# }
# #T_f74a9_row0_col8 {
#   background-color: #bb764b;
#   color: #f1f1f1;
# }
# #T_f74a9_row0_col9, #T_f74a9_row0_col18, #T_f74a9_row1_col0, #T_f74a9_row1_col2, #T_f74a9_row1_col3, #T_f74a9_row1_col4, #T_f74a9_row1_col15, #T_f74a9_row1_col16, #T_f74a9_row2_col5, #T_f74a9_row2_col6, #T_f74a9_row2_col7, #T_f74a9_row2_col8, #T_f74a9_row2_col10, #T_f74a9_row2_col11, #T_f74a9_row2_col12, #T_f74a9_row2_col14, #T_f74a9_row2_col19, #T_f74a9_row3_col1, #T_f74a9_row3_col13, #T_f74a9_row3_col17 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_f74a9_row0_col11 {
#   background-color: #452c1c;
#   color: #f1f1f1;
# }
# #T_f74a9_row0_col12, #T_f74a9_row3_col5 {
#   background-color: #ffa267;
#   color: #000000;
# }
# #T_f74a9_row0_col13 {
#   background-color: #26180f;
#   color: #f1f1f1;
# }
# #T_f74a9_row0_col14 {
#   background-color: #19100a;
#   color: #f1f1f1;
# }
# #T_f74a9_row0_col15 {
#   background-color: #e18e5b;
#   color: #f1f1f1;
# }
# #T_f74a9_row0_col16 {
#   background-color: #362216;
#   color: #f1f1f1;
# }
# #T_f74a9_row0_col17 {
#   background-color: #fa9e64;
#   color: #000000;
# }
# #T_f74a9_row0_col19 {
#   background-color: #070503;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col1 {
#   background-color: #8e5a39;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col5 {
#   background-color: #1e130c;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col6 {
#   background-color: #543522;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col7 {
#   background-color: #c77e50;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col8 {
#   background-color: #392417;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col10 {
#   background-color: #915b3a;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col11 {
#   background-color: #74492f;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col12 {
#   background-color: #d88957;
#   color: #f1f1f1;
# }
# #T_f74a9_row1_col14 {
#   background-color: #ffb070;
#   color: #000000;
# }
# #T_f74a9_row1_col18, #T_f74a9_row2_col9, #T_f74a9_row3_col9 {
#   background-color: #b17047;
#   color: #f1f1f1;
# }
# #T_f74a9_row2_col0, #T_f74a9_row2_col13 {
#   background-color: #342115;
#   color: #f1f1f1;
# }
# #T_f74a9_row2_col1 {
#   background-color: #ec955f;
#   color: #f1f1f1;
# }
# #T_f74a9_row2_col3 {
#   background-color: #c27b4e;
#   color: #f1f1f1;
# }
# #T_f74a9_row2_col4 {
#   background-color: #de8d5a;
#   color: #f1f1f1;
# }
# #T_f74a9_row2_col16 {
#   background-color: #fb9f65;
#   color: #000000;
# }
# #T_f74a9_row2_col17 {
#   background-color: #dc8b59;
#   color: #f1f1f1;
# }
# #T_f74a9_row3_col0 {
#   background-color: #ffad6e;
#   color: #000000;
# }
# #T_f74a9_row3_col2 {
#   background-color: #ffb774;
#   color: #000000;
# }
# #T_f74a9_row3_col4 {
#   background-color: #8c5838;
#   color: #f1f1f1;
# }
# #T_f74a9_row3_col6 {
#   background-color: #3d2618;
#   color: #f1f1f1;
# }
# #T_f74a9_row3_col7 {
#   background-color: #533421;
#   color: #f1f1f1;
# }
# #T_f74a9_row3_col15 {
#   background-color: #ffab6d;
#   color: #000000;
# }
# #T_f74a9_row3_col18 {
#   background-color: #e3905c;
#   color: #f1f1f1;
# }
# #T_f74a9_row3_col19 {
#   background-color: #ad6d46;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f74a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f74a9_level0_col0" class="col_heading level0 col0" colspan="20">count</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Years at Current Job</th>
#       <th id="T_f74a9_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_f74a9_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_f74a9_level1_col2" class="col_heading level1 col2" >2</th>
#       <th id="T_f74a9_level1_col3" class="col_heading level1 col3" >3</th>
#       <th id="T_f74a9_level1_col4" class="col_heading level1 col4" >4</th>
#       <th id="T_f74a9_level1_col5" class="col_heading level1 col5" >5</th>
#       <th id="T_f74a9_level1_col6" class="col_heading level1 col6" >6</th>
#       <th id="T_f74a9_level1_col7" class="col_heading level1 col7" >7</th>
#       <th id="T_f74a9_level1_col8" class="col_heading level1 col8" >8</th>
#       <th id="T_f74a9_level1_col9" class="col_heading level1 col9" >9</th>
#       <th id="T_f74a9_level1_col10" class="col_heading level1 col10" >10</th>
#       <th id="T_f74a9_level1_col11" class="col_heading level1 col11" >11</th>
#       <th id="T_f74a9_level1_col12" class="col_heading level1 col12" >12</th>
#       <th id="T_f74a9_level1_col13" class="col_heading level1 col13" >13</th>
#       <th id="T_f74a9_level1_col14" class="col_heading level1 col14" >14</th>
#       <th id="T_f74a9_level1_col15" class="col_heading level1 col15" >15</th>
#       <th id="T_f74a9_level1_col16" class="col_heading level1 col16" >16</th>
#       <th id="T_f74a9_level1_col17" class="col_heading level1 col17" >17</th>
#       <th id="T_f74a9_level1_col18" class="col_heading level1 col18" >18</th>
#       <th id="T_f74a9_level1_col19" class="col_heading level1 col19" >19</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education Level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f74a9_level0_row0" class="row_heading level0 row0" >Bachelor's</th>
#       <td id="T_f74a9_row0_col0" class="data row0 col0" >197</td>
#       <td id="T_f74a9_row0_col1" class="data row0 col1" >203</td>
#       <td id="T_f74a9_row0_col2" class="data row0 col2" >195</td>
#       <td id="T_f74a9_row0_col3" class="data row0 col3" >189</td>
#       <td id="T_f74a9_row0_col4" class="data row0 col4" >205</td>
#       <td id="T_f74a9_row0_col5" class="data row0 col5" >204</td>
#       <td id="T_f74a9_row0_col6" class="data row0 col6" >198</td>
#       <td id="T_f74a9_row0_col7" class="data row0 col7" >199</td>
#       <td id="T_f74a9_row0_col8" class="data row0 col8" >185</td>
#       <td id="T_f74a9_row0_col9" class="data row0 col9" >158</td>
#       <td id="T_f74a9_row0_col10" class="data row0 col10" >193</td>
#       <td id="T_f74a9_row0_col11" class="data row0 col11" >190</td>
#       <td id="T_f74a9_row0_col12" class="data row0 col12" >190</td>
#       <td id="T_f74a9_row0_col13" class="data row0 col13" >191</td>
#       <td id="T_f74a9_row0_col14" class="data row0 col14" >187</td>
#       <td id="T_f74a9_row0_col15" class="data row0 col15" >185</td>
#       <td id="T_f74a9_row0_col16" class="data row0 col16" >198</td>
#       <td id="T_f74a9_row0_col17" class="data row0 col17" >181</td>
#       <td id="T_f74a9_row0_col18" class="data row0 col18" >187</td>
#       <td id="T_f74a9_row0_col19" class="data row0 col19" >194</td>
#     </tr>
#     <tr>
#       <th id="T_f74a9_level0_row1" class="row_heading level0 row1" >High School</th>
#       <td id="T_f74a9_row1_col0" class="data row1 col0" >167</td>
#       <td id="T_f74a9_row1_col1" class="data row1 col1" >194</td>
#       <td id="T_f74a9_row1_col2" class="data

# %%
sns.boxplot(data=data, x='Education Level', y='Income')
plt.title('Income by Education Level')
plt.xticks(rotation=45)
plt.show()

# %%
averge_loan_credit_score=pd.DataFrame(data.groupby('Education Level')[['Credit Score', 'Loan Amount']].mean())
averge_loan_credit_score.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ba219_row0_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_ba219_row0_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_ba219_row1_col0, #T_ba219_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ba219_row2_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_ba219_row2_col1, #T_ba219_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ba219_row3_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ba219" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba219_level0_col0" class="col_heading level0 col0" >Credit Score</th>
#       <th id="T_ba219_level0_col1" class="col_heading level0 col1" >Loan Amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education Level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba219_level0_row0" class="row_heading level0 row0" >Bachelor's</th>
#       <td id="T_ba219_row0_col0" class="data row0 col0" >698.611747</td>
#       <td id="T_ba219_row0_col1" class="data row0 col1" >27324.702239</td>
#     </tr>
#     <tr>
#       <th id="T_ba219_level0_row1" class="row_heading level0 row1" >High School</th>
#       <td id="T_ba219_row1_col0" class="data row1 col0" >697.654688</td>
#       <td id="T_ba219_row1_col1" class="data row1 col1" >27299.832071</td>
#     </tr>
#     <tr>
#       <th id="T_ba219_level0_row2" class="row_heading level0 row2" >Master's</th>
#       <td id="T_ba219_row2_col0" class="data row2 col0" >698.959757</td>
#       <td id="T_ba219_row2_col1" class="data row2 col1" >27591.294156</td>
#     </tr>
#     <tr>
#       <th id="T_ba219_level0_row3" class="row_heading level0 row3" >PhD</th>
#       <td id="T_ba219_row3_col0" class="data row3 col0" >701.222990</td>
#       <td id="T_ba219_row3_col1" class="data row3 col1" >27588.624190</td>
#     </tr>
#   </tbody>
# </table>

# %%
gender_loan=pd.DataFrame(data.groupby('Gender')['Loan Purpose'].value_counts())
gender_loan.plot(kind='bar',figsize=(10,5),color=['pink'])
plt.title('Gender and loan purpose bar chart')
plt.xlabel('Gener and loan purpose')
plt.ylabel('Count of values')
plt.show()

# %%
employe_risk=pd.DataFrame(data.groupby(['Employment Status', 'Risk Rating'])['Gender'].value_counts())
employe_risk.unstack().style.background_gradient(cmap='Reds_r')
# Out:
# <style type="text/css">
# #T_1f8ed_row0_col0 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_1f8ed_row0_col1, #T_1f8ed_row6_col1 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_1f8ed_row0_col2 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_1f8ed_row1_col0, #T_1f8ed_row4_col1, #T_1f8ed_row4_col2, #T_1f8ed_row7_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_1f8ed_row1_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_1f8ed_row1_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_1f8ed_row2_col0 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_1f8ed_row2_col1 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_1f8ed_row2_col2, #T_1f8ed_row8_col0 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_1f8ed_row3_col0, #T_1f8ed_row3_col2 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_1f8ed_row3_col1, #T_1f8ed_row6_col0, #T_1f8ed_row6_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1f8ed_row4_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_1f8ed_row5_col0 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_1f8ed_row5_col1 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_1f8ed_row5_col2 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_1f8ed_row7_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_1f8ed_row7_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_1f8ed_row8_col1 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_1f8ed_row8_col2 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1f8ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f8ed_level0_col0" class="col_heading level0 col0" colspan="3">count</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Gender</th>
#       <th id="T_1f8ed_level1_col0" class="col_heading level1 col0" >Female</th>
#       <th id="T_1f8ed_level1_col1" class="col_heading level1 col1" >Male</th>
#       <th id="T_1f8ed_level1_col2" class="col_heading level1 col2" >Non-binary</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Employment Status</th>
#       <th class="index_name level1" >Risk Rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f8ed_level0_row0" class="row_heading level0 row0" rowspan="3">Employed</th>
#       <th id="T_1f8ed_level1_row0" class="row_heading level1 row0" >High</th>
#       <td id="T_1f8ed_row0_col0" class="data row0 col0" >169</td>
#       <td id="T_1f8ed_row0_col1" class="data row0 col1" >175</td>
#       <td id="T_1f8ed_row0_col2" class="data row0 col2" >173</td>
#     </tr>
#     <tr>
#       <th id="T_1f8ed_level1_row1" class="row_heading level1 row1" >Low</th>
#       <td id="T_1f8ed_row1_col0" class="data row1 col0" >997</td>
#       <td id="T_1f8ed_row1_col1" class="data row1 col1" >952</td>
#       <td id="T_1f8ed_row1_col2" class="data row1 col2" >1015</td>
#     </tr>
#     <tr>
#       <th id="T_1f8ed_level1_row2" class="row_heading level1 row2" >Medium</th>
#       <td id="T_1f8ed_row2_col0" class="data row2 col0" >543</td>
#       <td id="T_1f8ed_row2_col1" class="data row2 col1" >521</td>
#       <td id="T_1f8ed_row2_col2" class="data row2 col2" >481</td>
#     </tr>
#     <tr>
#       <th id="T_1f8ed_level0_row3" class="row_heading level0 row3" rowspan="3">Self-employed</th>
#       <th id="T_1f8ed_level1_row3" class="row_heading level1 row3" >High</th>
#       <td id="T_1f8ed_row3_col0" class="data row3 col0" >186</td>
#       <td id="T_1f8ed_row3_col1" class="data row3 col1" >164</td>
#       <td id="T_1f8ed_row3_col2" class="data row3 col2" >160</td>
#     </tr>
#     <tr>
#       <th id="T_1f8ed_level1_row4" class="row_heading level1 row4" >Low</th>
#       <td id="T_1f8ed_row4_col0" class="data row4 col0" >987</td>
#       <td id="T_1f8ed_row4_col1" class="data row4 col1" >988</td>
#       <td id="T_1f8ed_row4_col2" class="data row4 col2" >1045</td>
#     </tr>
#     <tr>
#       <th id="T_1f8ed_level1_row5" class="row_heading level1 row5" >Medium</th>
#       <td id="T_1f8ed_row5_col0" class="data row5 col0" >466</td>
#       <td id="T_1f8ed_row5_col1" class="data row5 col1" >502</td>
#       <td id="T_1f8ed_row5_col2" class="data row5 col2" >493</td>
#     </tr>
#     <tr>
#       <th id="T_1f8ed_level0_row6" class="row_heading level0 row6" rowspan="3">Unemployed</th>
#       <th id="T_1f8ed_level1_row6" class="row_heading level1 row6" >High</th>
#       <td id="T_1f8ed_row6_col0" class="data row6 col0" >163</td>
#       <td id="T_1f8ed_row6_col1" class="data row6 col1" >176</td>
#       <td id="T_1f8ed_row6_col2" class="data row6 col2" >134</td>
#     </tr>
#     <tr>
#       <th id="T_1f8ed_level1_row7" class="row_heading level1 row7" >Low</th>
#       <td id="T_1f8ed_row7_col0" class="data row7 col0" >997</td>
#       <td id="T_1f8ed_row7_col1" class="data row7 col1" >981</td>
#       <td id="T_1f8ed_row7_col2" class="data row7 col2" >1038</td>
#     </tr>
#     <tr>
#       <th id="T_1f8ed_level1_row8" class="row_heading level1 row8" >Medium</th>
#       <td id="T_1f8ed_row8_col0" class="data row8 col0" >482</td>
#       <td id="T_1f8ed_row8_col1" class="data row8 col1" >492</td>
#       <td id="T_1f8ed_row8_col2" class="data row8 col2" >520</td>
#     </tr>
#   </tbody>
# </table>

# %%
cate=data.select_dtypes(include='object')
cate.head()
# Out:
#        Gender Education Level Marital Status Loan Purpose Employment Status  \
# 0        Male             PhD       Divorced     Business        Unemployed
# 1      Female      Bachelor's        Widowed         Auto          Employed
# 2  Non-binary        Master's         Single         Home          Employed
# 3        Male      Bachelor's         Single     Personal        Unemployed
# 4  Non-binary      Bachelor's        Widowed     Personal        Unemployed
#
#   Payment History             City State       Country Risk Rating
# 0            Poor   Port Elizabeth    AS        Cyprus         Low
# 1            Fair  North Catherine    OH  Turkmenistan      Medium
# 2            Fair      South Scott    OK    Luxembourg      Medium
# 3       Excellent       Robinhaven    PR        Uganda      Medium
# 4            Fair      New Heather    IL       Namibia         Low

# %%
plt.figure(figsize=(10,5))
sns.relplot(data=data[:400],x='Income',y='Loan Amount',hue='Risk Rating')
plt.title('Relations between income and loan amount with risk rating')
plt.xlabel('Income')
plt.ylabel('Loan Amount')
plt.show()
